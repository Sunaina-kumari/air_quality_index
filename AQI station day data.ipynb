# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from nltk import *

# %%
from datetime import datetime
import calendar

# %%
a=pd.read_csv('station_day.csv')
a
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
len(a['StationId'].unique())
# Out:
# 91

# %%
a.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# PM10          42706
# NO            17106
# NO2           16547
# NOx           15500
# NH3           48105
# CO            12998
# SO2           25204
# O3            25568
# Benzene       31455
# Toluene       38702
# Xylene        85137
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
a.drop(['Xylene','Toluene','Benzene','NH3','PM10'],axis=1,inplace=True)

# %%
a.shape
# Out:
# (108035, 11)

# %%
a.isnull().sum()
# Out:
# StationId         0
# Date              0
# PM2.5         21625
# NO            17106
# NO2           16547
# NOx           15500
# CO            12998
# SO2           25204
# O3            25568
# AQI           21010
# AQI_Bucket    21010
# dtype: int64

# %%
a.drop('PM2.5',axis=1,inplace=True)

# %%
a.dropna(inplace=True)

# %%
a.shape
# Out:
# (64268, 10)

# %%
a.reset_index(drop=True,inplace=True)

# %%
a['Year']=a['Date'][:]

# %%
a['Year'][28][0:4]
# Out:
# '2017'

# %%
a['Year']=a['Year'].apply(lambda x:x[0:4])

# %%
a['Month']=a['Date'].apply(lambda x:calendar.month_abbr[int(x[5:7])])

# %%
a
# Out:
#       StationId        Date     NO     NO2     NOx    CO    SO2      O3  \
# 0         AP001  2017-11-25   1.44   20.50   12.08  0.12  15.24  127.09
# 1         AP001  2017-11-26   1.26   26.00   14.85  0.14  26.96  117.44
# 2         AP001  2017-11-27   6.60   30.85   21.77  0.11  33.59  111.81
# 3         AP001  2017-11-28   2.56   28.07   17.01  0.09  19.00  138.18
# 4         AP001  2017-11-29   5.23   23.20   16.59  0.16  10.55  109.74
# ...         ...         ...    ...     ...     ...   ...    ...     ...
# 64263     WB013  2020-06-25   3.23   11.42   14.65  0.57  11.39   31.76
# 64264     WB013  2020-06-26  23.51   16.50   40.02  0.66  10.34   30.19
# 64265     WB013  2020-06-29  13.65  200.87  214.20  0.78   5.12   38.17
# 64266     WB013  2020-06-30   7.56   29.13   36.69  0.69   5.88   29.64
# 64267     WB013  2020-07-01   7.78   22.50   30.25  0.58   2.80   13.10
#
#          AQI    AQI_Bucket  Year Month
# 0      184.0      Moderate  2017   Nov
# ...

# %%
g=a.groupby('Year')
y15=g.get_group('2015')
y16=g.get_group('2016')
y17=g.get_group('2017')
y18=g.get_group('2018')
y19=g.get_group('2019')
y20=g.get_group('2020')
y20
# Out:
#       StationId        Date     NO     NO2     NOx    CO    SO2     O3   AQI  \
# 653       AP001  2020-01-01   1.67   12.12    7.81  0.77  17.53  57.26  96.0
# 654       AP001  2020-01-02   1.72   12.17    7.87  0.73  17.09  55.17  82.0
# 655       AP001  2020-01-03   1.81   13.53    8.67  0.69  22.14  43.70  76.0
# 656       AP001  2020-01-04   2.27   18.79   11.83  0.64  19.87  23.59  47.0
# 657       AP001  2020-01-05   1.73   12.98    8.31  0.63  14.68  36.53  55.0
# ...         ...         ...    ...     ...     ...   ...    ...    ...   ...
# 64263     WB013  2020-06-25   3.23   11.42   14.65  0.57  11.39  31.76  56.0
# 64264     WB013  2020-06-26  23.51   16.50   40.02  0.66  10.34  30.19  50.0
# 64265     WB013  2020-06-29  13.65  200.87  214.20  0.78   5.12  38.17  63.0
# 64266     WB013  2020-06-30   7.56   29.13   36.69  0.69   5.88  29.64  57.0
# 64267     WB013  2020-07-01   7.78   22.50   30.25  0.58   2.80  13.10  59.0
#
#          AQI_Bucket  Year Month
# ...

# %%
len(a['StationId'].unique())
# Out:
# 91
